# %% [markdown]
# örnek olarak  amacımız : e ticaret siteleri için pazarlama stratejileri geliştirmek olsun
#
# diyalog:
# e-ticaret sitesi : elimizde veriler var hangi müşteriye hangi ürünü önermeliyiz bunu öğrenmek istiyoruz .
#
# biz: 1-verinini içeriği nedir (veri içeriğini bizim eblirlememiz gerekiyor konum maas harcamalari vs... )
#      kime :müşteri segmentasyonu
#      hangi urun :recomendetation system
#
# musteri_segmentasyonu verisi verdiler bize biz de bu doğrultuda ürün önerme işlemi yapacağız

# %% [markdown]
# ### yapılacak-1) Veriyi incelemek

# %% [markdown]
# ##### Kütüphaneleri içeri aktarma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

from scipy.cluster.hierarchy import linkage, dendrogram

# %% [markdown]
# ### yapılacak-2) clustering modeli oluşturmak unsupervised learning(kmeans)

# %% [markdown]
# ### yapılacak-3) Veriyi Görselleştirmek(dendogram)
